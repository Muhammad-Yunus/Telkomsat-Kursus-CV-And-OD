# %% [markdown]
# ## 6.1 Datasheet Annotation for Yolo v11 Segmentation
# - Download datasheet [Batang Pohon.zip](https://drive.google.com/file/d/1y_iRwaTQ63NICfIlFbR06NAmjTg3Q-VN/view?usp=sharing)
# - Doing similar task to annotate datasheet using Roboflow like in the notebook [5.1 dataset_annotation_roboflow.ipynb](../Pertemuan_5/5.1 dataset_annotation_roboflow.ipynb)
# - Set Project Name to : Deteksi Batang Pohon
# - Set Group : batang_pohon
# - Setup Auto Annotation :
#     - Set class name : batang_pohon
#     - set visual description : a tree trunk cross-section
