# %% [markdown]
# ### 5.1 Dataset Annotation using Roboflow
# - Understanding Dataset Annotation
# - Create Roboflow Account, Create Workspace & Create Project
# - Upload Dataset
# - Manual Annotation

# %% [markdown]
# ### 5.1.1 Undestanding Dataset Annotation
#
# - Dataset adalah kumpulan data yang kita butuhkan untuk proses training model.<br>
# - Dalam object detectin menggunakan Yolo, dataset berupa kumpulan gambar yang terbagi dalam class-class data.
# - Satu class data memiliki kesamaan `fitur`.
# - Misalkan class data `kucing` maka gambar-gambar yang terasosiasi pada class tersebut adalah class kucing.
# <img src="resource/training-inferencing.jpg" width="600px">

# %% [markdown]
# ### 5.1.2 Create Roboflow
#
# - Buka di browser link berikut https://app.roboflow.com/ <br>
# <img src="resource/rb-login.png" width="500px">
# - Pilih login dengan akun google.
# - Check `confirm checkbox` lalu `continue`<br>
# <img src="resource/rb-confirm.png" width="500px">
# - Setelah itu akan muncul halaman create `Workspace`
# - Input nama workspace `Learning`, pilin `Free plan` lalu click `Create Workspace`
# <img src="resource/rb-create-workspace.png" width="800px">
# - Setelah itu click `Continue without adding others`<br>
# <img src="resource/rb-invite.png" width="500px">

# %% [markdown]
# ### 5.1.3 Create & Upload Dataset
# - Create dataset dengan nama `Plane Detection` dana annotation group `plane`
# - Pilih project type `Object Detection` lalu klik `Create public project`<br>
# <img src="resource/rb (1).png" width="800px"><br><br>
# - Pilih `Use Traditional Model Instead`<br>
# <img src="resource/rb (2).png" width="800px"><br><br>
# - Setelah itu download sample dataset dari link berikut [Plane Datasets](https://drive.google.com/file/d/1X7pIvYqELsbYvQwFtMxYOSALRPyf6tct/view?usp=sharing)
# <br>
# - Upload ke dalam  `Plane Detection` project dengan cara klik `Select Files`<br>
# <img src="resource/rb (3).png" width="800px"><br><br>
# - Tunngu sampai Proses Upload Selesai <br>
# <img src="resource/rb (4).png" width="800px"><br><br>
# - Setelah itu klik `Auto-Label Entire Batch` <br>
# <img src="resource/rb (5).png" width="800px"><br><br>

# %% [markdown]
# ### 5.1.4 Setup Auto Labeling & Datsheet Vesioning
# - click `Get Started` <br>
# <img src="resource/rb (6).png" width="800px"><br><br>
# - set class name to `airplane` and set visual description to `airplane` then click `Generate Test Result` <br>
# <img src="resource/rb (7).png" width="800px"><br><br>
# - click `Auto Label with This Model` <br>
# <img src="resource/rb (8).png" width="800px"><br><br>
# - click `Start Auto Label` <br>
# <img src="resource/rb (9).png" width="800px"><br><br>
# - wait until autolabel completed, then open it when completed, <br>
# <img src="resource/rb (11).png" width="800px"><br><br>
# - click on first image datasheet to view annotated result,<br>
# <img src="resource/rb (12).png" width="800px"><br><br>
# - set 1st, 2nd and 3rd sample into Validation Set<br>
# <img src="resource/rb (14).png" width="800px"><br><br>
# - set 1st, 2nd and 3rd sample into Test Set<br>
# <img src="resource/rb (15).png" width="800px"><br><br>
# - click `Approve All`<br>
# <img src="resource/rb (17).png" width="800px"><br><br>
# - click `Add Approved to Datasheet`<br>
# <img src="resource/rb (18).png" width="800px"><br><br>
# - click `Add xx Images`<br>
# <img src="resource/rb (19).png" width="800px"><br><br>
# - click `New Datasheet Version`<br>
# <img src="resource/rb (21).png" width="800px"><br><br>
# - click `Add Preprocessing Step`<br>
# <img src="resource/rb (22).png" width="800px"><br><br>
# - choose `Crop`<br>
# <img src="resource/rb (23).png" width="800px"><br><br>
# - set size `512x512` then click `Apply`<br>
# <img src="resource/rb (24).png" width="800px"><br><br>
# - click `Add Augmentation Step`<br>
# <img src="resource/rb (26).png" width="800px"><br><br>
# - add one by one `Flip`, `Crop`, `Rotation` & `Brightness` Augmentation<br>
# <img src="resource/rb (27).png" width="800px"><br><br>
# - it's should look like this, the click `continue`<br>
# <img src="resource/rb (28).png" width="800px"><br><br>
# - click `Create`<br>
# <img src="resource/rb (29).png" width="800px"><br><br>
# - click `Download Datasheet`<br>
# <img src="resource/rb (31).png" width="800px"><br><br>
# - choose formate `YOLO v11` and download option to `Show Download Code`<br>
# <img src="resource/rb (34).png" width="800px"><br><br>
# - then copy the code<br>
# <img src="resource/rb (35).png" width="800px"><br><br>
